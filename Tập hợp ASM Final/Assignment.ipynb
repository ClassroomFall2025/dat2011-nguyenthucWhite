# %%
# Viết ASM 1
# YÊU CẦU:
# Y1. Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.
# Y2. Đọc thông tin nhân viên từ file và xuất danh sách nhân viên ra màn hình.
# Y3. Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.
# Y4. Xóa nhân viên theo mã nhập từ bàn phím. Cập nhật file dữ liệu.
# Y5. Cập nhật thông tin nhân vidên theo mã nhập từ bàn phím và ghi thay đổi vào file.
# Y6. Tìm các nhân viên theo khoảng lương nhập từ bàn phím.
# Y7. Sắp xếp nhân viên theo họ và tên.
# Y8. Sắp xếp nhân viên theo thu nhập.
# Y9. Xuất 5 nhân viên có thu nhập cao nhất.

# • Final Assignment
# o Kiểm các lỗi dữ liệu nhập vào từ bàn phím
# o Hoàn thiện yêu cầu 1: lưu thông tin nhân viên vào file
# o Thực hiện yêu cầu 2: đọc thông tin nhân viên từ file, lưu vào danh sách và xuất ra màn hình
# o Thực hiện các yêu cầu 4 và 5.
import Assignment
while True:
    print(10*"===", ":Menu:", 10*"===")
    print("1. Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.")
    print("2. Đọc thông tin nhân viên từ file và xuất danh sách nhân viên.")
    print("3. Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.")
    print("4. Xóa nhân viên theo mã nhập. Cập nhật file dữ liệu.")
    print("5. Cập nhật thông tin nhân viên theo mã nhập và ghi thay đổi vào file.")
    print("6. Tìm các nhân viên theo khoảng lương nhập từ bàn phím.")
    print("7. Sắp xếp nhân viên theo họ và tên.")
    print("8. Sắp xếp nhân viên theo thu nhập.")
    print("9. Xuất 5 nhân viên có thu nhập cao nhất.")
    print("10. Thoát chương trình.")
    print(10*"===", ":Menu:", 10*"===")
    Lựa_chọn = input("Nhập lựa chọn của bạn (1-10): ")
    print()
    if Lựa_chọn == '1':
        Assignment.cn1()
    elif Lựa_chọn == '2':
        Assignment.cn2()
    elif Lựa_chọn == '3':
        Assignment.cn3()
    elif Lựa_chọn == '4':
        Assignment.cn4()
    elif Lựa_chọn == '5':
        Assignment.cn5()
    elif Lựa_chọn == '6':
        Assignment.cn6()
    elif Lựa_chọn == '7':
        Assignment.cn7()
    elif Lựa_chọn == '8':
        Assignment.cn8()
    elif Lựa_chọn == '9':
        Assignment.cn9()
    elif Lựa_chọn == '10':
        Assignment.cn10()
        break
    else:
        print("Lựa chọn không hợp lệ. Vui lòng chọn lại.")
    print()
# Out:
# ============================== :Menu: ==============================
# 1. Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.
# 2. Đọc thông tin nhân viên từ file và xuất danh sách nhân viên.
# 3. Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.
# 4. Xóa nhân viên theo mã nhập. Cập nhật file dữ liệu.
# 5. Cập nhật thông tin nhân viên theo mã nhập và ghi thay đổi vào file.
# 6. Tìm các nhân viên theo khoảng lương nhập từ bàn phím.
# 7. Sắp xếp nhân viên theo họ và tên.
# 8. Sắp xếp nhân viên theo thu nhập.
# 9. Xuất 5 nhân viên có thu nhập cao nhất.
# 10. Thoát chương trình.
# ============================== :Menu: ==============================
#
# Chức năng 1: Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.
# Nhập thông tin nhân viên thứ 1:
# NV,PS123,A,7000000.0,7000000.0
# Nhập thông tin nhân viên thứ 2:
# NV,PS456,B,7000000.0,7000000.0
# Nhập thông tin nhân viên thứ 3:
# NV,PS789,C,7000000.0,7000000.0
# Nhập thông tin nhân viên thứ 4:
# TT,PI123,D,9000000.0,0.05,50.0,9000002.5
# Nhập thông tin nhân viên thứ 5:
# TP,PU123,T,20000000.0,30000000.0,50000000.0
# Đã nhập xong danh sách nhân viên:
# NV,PS123,A,7000000.0,7000000.0
# NV,PS456,B,7000000.0,7000000.0
# NV,PS789,C,7000000.0,7000000.0
# TT,PI123,D,9000000.0,0.05,50.0,9000002.5
# TP,PU123,T,20000000.0,30000000.0,50000000.0
# Đã lưu danh sách vào file danh_sach_nhan_vien.csv.
#
# ============================== :Menu: ==============================
# 1. Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.
# 2. Đọc thông tin nhân viên từ file và xuất danh sách nhân viên.
# 3. Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.
# 4. Xóa nhân viên theo mã nhập. Cập nhật file dữ liệu.
# 5. Cập nhật thông tin nhân viên theo mã nhập và ghi thay đổi vào file.
# 6. Tìm các nhân viên theo khoảng lương nhập từ bàn phím.
# 7. Sắp xếp nhân viên theo họ và tên.
# 8. Sắp xếp nhân viên theo thu nhập.
# 9. Xuất 5 nhân viên có thu nhập cao nhất.
# 10. Thoát chương trình.
# ============================== :Menu: ==============================
#
# Chức năng 2: Đọc thông tin nhân viên từ file và xuất danh sách nhân viên
# Đã đọc 5 nhân viên từ file danh_sach_nhan_vien.csv:
# NV,PS123,A,7000000.0,7000000.0
# NV,PS456,B,7000000.0,7000000.0
# NV,PS789,C,7000000.0,7000000.0
# TT,PI123,D,9000000.0,0.05,50.0,9000002.5
# TP,PU123,T,20000000.0,30000000.0,50000000.0
#
# ============================== :Menu: ==============================
# 1. Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.
# 2. Đọc thông tin nhân viên từ file và xuất danh sách nhân viên.
# 3. Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.
# 4. Xóa nhân viên theo mã nhập. Cập nhật file dữ liệu.
# 5. Cập nhật thông tin nhân viên theo mã nhập và ghi thay đổi vào file.
# 6. Tìm các nhân viên theo khoảng lương nhập từ bàn phím.
# 7. Sắp xếp nhân viên theo họ và tên.
# 8. Sắp xếp nhân viên theo thu nhập.
# 9. Xuất 5 nhân viên có thu nhập cao nhất.
# 10. Thoát chương trình.
# ============================== :Menu: ==============================
#
# Chức năng 3: Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.
# Thông tin nhân viên:
# NV,PS123,A,7000000.0,7000000.0
#
# ============================== :Menu: ==============================
# 1. Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.
# 2. Đọc thông tin nhân viên từ file và xuất danh sách nhân viên.
# 3. Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.
# 4. Xóa nhân viên theo mã nhập. Cập nhật file dữ liệu.
# 5. Cập nhật thông tin nhân viên theo mã nhập và ghi thay đổi vào file.
# 6. Tìm các nhân viên theo khoảng lương nhập từ bàn phím.
# 7. Sắp xếp nhân viên theo họ và tên.
# 8. Sắp xếp nhân viên theo thu nhập.
# 9. Xuất 5 nhân viên có thu nhập cao nhất.
# 10. Thoát chương trình.
# ============================== :Menu: ==============================
#
# Chức năng 4: Xóa nhân viên theo mã nhập từ bàn phím. Cập nhật file dữ liệu.
# Đã lưu danh sách vào file danh_sach_nhan_vien.csv.
# Đã xóa nhân viên có mã PS123.
#
# ============================== :Menu: ==============================
# 1. Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.
# 2. Đọc thông tin nhân viên từ file và xuất danh sách nhân viên.
# 3. Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.
# 4. Xóa nhân viên theo mã nhập. Cập nhật file dữ liệu.
# 5. Cập nhật thông tin nhân viên theo mã nhập và ghi thay đổi vào file.
# 6. Tìm các nhân viên theo khoảng lương nhập từ bàn phím.
# 7. Sắp xếp nhân viên theo họ và tên.
# 8. Sắp xếp nhân viên theo thu nhập.
# 9. Xuất 5 nhân viên có thu nhập cao nhất.
# 10. Thoát chương trình.
# ============================== :Menu: ==============================
#
# Chức năng 5: Cập nhật thông tin nhân viên theo mã nhập từ bàn phím và ghi thay đổi vào file.
# Không tìm thấy nhân viên có mã PS147.
#
# ============================== :Menu: ==============================
# 1. Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.
# 2. Đọc thông tin nhân viên từ file và xuất danh sách nhân viên.
# 3. Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.
# 4. Xóa nhân viên theo mã nhập. Cập nhật file dữ liệu.
# 5. Cập nhật thông tin nhân viên theo mã nhập và ghi thay đổi vào file.
# 6. Tìm các nhân viên theo khoảng lương nhập từ bàn phím.
# 7. Sắp xếp nhân viên theo họ và tên.
# 8. Sắp xếp nhân viên theo thu nhập.
# 9. Xuất 5 nhân viên có thu nhập cao nhất.
# 10. Thoát chương trình.
# ============================== :Menu: ==============================
#
# Chức năng 5: Cập nhật thông tin nhân viên theo mã nhập từ bàn phím và ghi thay đổi vào file.
# Đã tìm thấy nhân viên. Vui lòng nhập thông tin mới (Giữ nguyên mã):
# Đã lưu danh sách vào file danh_sach_nhan_vien.csv.
# Đã cập nhật thông tin cho nhân viên mã PS456.
#
# ============================== :Menu: ==============================
# 1. Nhập danh sách nhân viên từ bàn phím. Lưu thông tin nhân viên vào file.
# 2. Đọc thông tin nhân viên từ file và xuất danh sách nhân viên.
# 3. Tìm và hiển thị nhân viên theo mã nhập từ bàn phím.
# 4. Xóa nhân viên theo mã nhập. Cập nhật file dữ liệu.
# 5. Cập nhật thông tin nhân viên theo mã nhập và ghi thay đổi vào file.
# 6. Tìm các nhân viên theo khoảng lương nhập từ bàn phím.
# 7. Sắp xếp nhân viên theo họ và tên.
# 8. Sắp xếp nhân viên theo thu nhập.
# 9. Xuất 5 nhân viên có thu nhập cao nhất.
# 10. Thoát chương trình.
# ============================== :Menu: ==============================
#
# Chức năng 10: Thoát chương trình.
# Kết thúc chương trình.
